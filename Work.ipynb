# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewStaines/AIML/blob/main/Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df['Species']=enc.fit_transform(df.Species)
y_tr = df["Species"]
df.drop(columns=['Species', 'Id'],axis=1,inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
# x_tr = df.values[0:75]
# x_te = df.values[75:]

# %%
# from sklearn.preprocessing import MinMaxScaler

# scl = MinMaxScaler()
# x_tr_scl = scl.fit_transform(x_tr)
# x_te_scl = scl.transform(x_te)

# %%
from sklearn.model_selection import train_test_split
x_trs,x_tes,y_trs,y_tes = train_test_split(df,y_tr,random_state=0)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
lr = [0.05,0.1,0.25,0.5,0.75,1]
for i in lr:
  gb=GradientBoostingClassifier(n_estimators=2, learning_rate=i , max_features=2, max_depth=2, random_state= 0)
  gb.fit(x_trs,y_trs)
  print("Learning Rate:\n",i)
  print("Training {0:.3f}".format(gb.score(x_trs, y_trs)))
  print("Validate {0:.3f}".format(gb.score(x_tes, y_tes)))
# Out:
# Learning Rate:
#  0.05
# Training 0.973
# Validate 0.974
# Learning Rate:
#  0.1
# Training 0.982
# Validate 0.974
# Learning Rate:
#  0.25
# Training 0.973
# Validate 0.974
# Learning Rate:
#  0.5
# Training 0.982
# Validate 0.947
# Learning Rate:
#  0.75
# Training 0.982
# Validate 0.974
# Learning Rate:
#  1
# Training 0.982
# Validate 0.974

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
for i in lr:
  ab=AdaBoostClassifier(n_estimators=1, learning_rate=i , random_state= 0)
  ab.fit(x_trs,y_trs)
  print("Learning Rate:\n",i)
  print("Training {0:.3f}".format(gb.score(x_trs, y_trs)))
  print("Validate {0:.3f}".format(gb.score(x_tes, y_tes)))
# Out:
# Learning Rate:
#  0.05
# Training 0.982
# Validate 0.974
# Learning Rate:
#  0.1
# Training 0.982
# Validate 0.974
# Learning Rate:
#  0.25
# Training 0.982
# Validate 0.974
# Learning Rate:
#  0.5
# Training 0.982
# Validate 0.974
# Learning Rate:
#  0.75
# Training 0.982
# Validate 0.974
# Learning Rate:
#  1
# Training 0.982
# Validate 0.974
